# %% [markdown]
# **Project Title : ROISim - Marketing Campaign ROI Simulation**

# %% [markdown]
# **Objective** : Simulate marketing campaign performance and calculate ROI under different budget and conversion scenarios.

# %% [markdown]
# **Business Context** : Marketing teams need to justify spend with measurable returns. ROI simulation helps forecast outcomes and optimize campaign strategy.

# %% [markdown]
# **Workflow Overview** :
# - Define campaign parameters (budget, CPC, conversion rate, revenue per conversion)
# - Simulate funnel outcomes
# - Calculate ROI
# - Run sensitivity analysis
# - Recommend budget strategy

# %%
# Step 1: Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Step 2: Define campaign parameters
budget = 100000  # ₹
cpc = 50         # ₹ per click
conversion_rate = 0.04
revenue_per_conversion = 1500  # ₹

# Step 3: Simulate funnel
clicks = budget / cpc
conversions = clicks * conversion_rate
revenue = conversions * revenue_per_conversion
roi = (revenue - budget) / budget

# Step 4: Print results
print(f"📊 Clicks: {clicks:.0f}")
print(f"✅ Conversions: {conversions:.0f}")
print(f"💰 Revenue: ₹{revenue:,.0f}")
print(f"📈 ROI: {roi*100:.2f}%")

# Step 5: Sensitivity analysis
conversion_rates = np.linspace(0.01, 0.10, 10)
roi_values = [(r * revenue_per_conversion * clicks - budget) / budget for r in conversion_rates]

plt.figure(figsize=(10,6))
plt.plot(conversion_rates, np.array(roi_values)*100, marker='o', color='darkorange')
plt.title('ROI Sensitivity to Conversion Rate')
plt.xlabel('Conversion Rate')
plt.ylabel('ROI (%)')
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# 📊 Clicks: 2000
# ✅ Conversions: 80
# 💰 Revenue: ₹120,000
# 📈 ROI: 20.00%

# %% [markdown]
# **Executive Summary** :
# - **Base ROI**: 20% on ₹100K spend
# - **Break-even Conversion Rate**: ~3.3%
# - **Recommendation**:
#   - Focus on improving conversion rate via landing page optimization
#   - Reallocate budget to channels with >4% conversion
#   - Use ROI simulation for quarterly campaign planning
# - **Impact**: ROI modeling supports smarter budget allocation and performance forecasting
